# %% [markdown]
# # Setings
#
# Bibliotecas usadas:
#
# - datetime
# - pandas
# - matplotlib
#
# - sys
# - json
# - glob
#
# - webvtt
#
# Outros:
#
# - Youtube API (https://developers.google.com/youtube/v3)
# - Youtube-dl (https://youtube-dl.org/)

# %% [markdown]
# ## Configurações básicas
#
# - Bibliotecas usadas
# - Diretórios e locais de trabalho

# %%
# Bibliotecas usadas

"""
Caso não tenha algumas das bibliotecas instaladas digitar "!pip install". Exemplo: !pip install os. 
Exceção para os casos YoutubeAPI e Youtube-dl. Nesses casos, acessar os links indicados e verificar os documentos disponíveis. 
"""

import os
import pandas as pd
from matplotlib import pyplot as plt

import sys
import datetime
import json
import glob

import webvtt

# %%
# Diretórios e locais de trabalho

cwd = os.getcwd()
print(cwd)
# Out:
# /Users/dumoura/Dev/PDev/PoliticalRemix/Lives_da_Semana/Notebook_IngDef/Bolsonorao_Channel_Parsing

# %%
# Definir diretórios e locais de trabalho

BASE_DIR = os.path.dirname(cwd) # base de trabalho
DATA_DIR = os.path.join(BASE_DIR, "data") # dados gerais levantados durante projeto
META_DIR = os.path.join(BASE_DIR, "metadados") #metadados levantados durante projeto
CACHE_DIR = os.path.join(BASE_DIR, "cache") # material em processo - pode ser apagado ao final, caso julgue necessário
LINK_DIR = os.path.join(BASE_DIR, "links") # material em processo - pode ser apagado ao final, caso julgue necessário
SUB_DIR = os.path.join(CACHE_DIR, "subs") # local de trabalho para processamento de legenda
VID_DIR = os.path.join(CACHE_DIR, "vids") # local de trabalho para processamento de legenda

# Criar diretórios e locais de trabalho

os.makedirs(DATA_DIR, exist_ok=True)
os.makedirs(META_DIR, exist_ok=True)
os.makedirs(CACHE_DIR, exist_ok=True)
os.makedirs(SUB_DIR, exist_ok=True)
os.makedirs(VID_DIR, exist_ok=True)
os.makedirs(LINK_DIR, exist_ok=True)

# %%
# Verificar se os diretórios e locais de trabalho foram criados corretamente
#os.listdir(BASE_DIR)

# %%
#contexto

now = datetime.datetime.now()
year = datetime.datetime.now().year
day = datetime.datetime.now().day
month = datetime.datetime.now().month

context = f"_{month}-{day}-{year}"

# %%
#print(context)

# %% [markdown]
# # Fazer pesquisa em conteúdo verbal de vídeos de um canal
#
# Objetivo de pesquisa:
# - Pesquisar/levantar o que está sendo dido (conteúdo verbal) pelo presidente sobre pandemia.
#
# Passos:
# - Selecionar link dos vídeos de corpus
#     - lives da semana
#
# - Fazer download da legenda de cada vídeo
# - Criar documento único
#     - dados que permitam recuperar informações significativas/contextuais (video, decupagem, conteúdo verbal - o que está sendo dido)
#
# - Criar Data Frame
# - Salvar documento em .csv

# %% [markdown]
# ### Selecionar link dos vídeos de corpus
#
# - lives da semana

# %%
os.listdir(META_DIR)
# Out:
# ['.DS_Store', 'LivesBolsonaro_Metadado_3-3-2021.csv']

# %%
# abrir documento geral JairChannel_corpusLives_LINKS_{context}
title = f"LivesBolsonaro_Metadado{context}"
df = pd.read_csv(f"{META_DIR}/{title}.csv")

# %%
len(df)
#print(df.videoId) 
#df.videoLink # aparentemente, o youtube-dl funciona melhor com link do que id
# Out:
# 97

# %% [markdown]
# ### Fazer download da legenda de cada vídeo em live da semana

# %%
# Levantar no diretório de cache/sub para baixar as legendas de cada vídeo - youtube-dl 
os.chdir(f"{SUB_DIR}")
print(os.getcwd())
# Out:
# /Users/dumoura/Dev/PDev/PoliticalRemix/Lives_da_Semana/Notebook_IngDef/cache/subs

# %%
# youtube-dl: para cada link em um arquivo [df] baixar o melhor formato de legenda automática em português [--write-auto-sub  --sub-format best], converter para vtt[--convert-subs vtt], não baixar os vídeos em si [--skip-download], ignorar erros [-i], salvar os arquivos e nomeá-los com o id do vídeo [--id]

for link in df.videoLink:
    os.system(f"youtube-dl {link} -i --id --write-auto-sub --sub-format best --convert-subs vtt --skip-download")

# %% [markdown]
# ### Criar documento único

# %%
# Criar documento único
## 1. listar em diretório todos os documentos terminados em '.vtt'

vtt_dir = SUB_DIR
vtt_root = os.path.join(vtt_dir, "*.vtt")
file_list = glob.glob(vtt_root)

len(file_list)
# Out:
# 77

# %%
### Criar documento único
## 2. criar Data Frame a partir de 'results' com as colunas id, start, end e text

# %%
results = []

for file in file_list:
    data = webvtt.read(file)
    
    for sub in data:
        
        _id = data.file
        start = sub.start  # start timestamp in text format
        end = sub.end  # end timestamp in text format
        text = sub.text  # caption text

        results.append([_id, start, end,  text])
        results_df = pd.DataFrame(results, columns=['id','start', 'end', 'text'])

# %%
# verificar results

for i in results_df.text:
    print(i)
# Out:
# it's good night everyone makes our farm lainé every Thursday at 7 pm
#  hours of the night and let's go here quickly at the most 15 minutes is to put you already
#  can happen is happening the government time são paulo today is celebrated
#  in advance the day of our success and there is not in mine there was what I
#  I said that in the press the press is important no one doubts
#  social media are also important
#  I said hurry that in spite of some mishaps between us is we must
#  understand why the flame of democracy is not extinguished or rather the press
#  functioning even some mishaps it is important for the maintenance of the
#  flame of democracy is that old story that old
#  story it's better the press sometimes get what they feel is the right press
#  such logically on my part I do want to talk to the press
#  we say what is important for every side over there is that we have two
#  good images written in newspapers good audios good true videos above
#  everything we can together right you can see the brazil place in the place that interests you
#  this way the Brazilian company is sure that here it is
#  always at your disposal a hug to everyone happiness seems like it was
#  revoked the minister himself flies the one that was opened for
#  investigate people but I don’t know which news and also that
#  article in the magazine what is it about the present of supplement 5 truth seems
#  which is true congratulations alexandre another article that
#  stirred up a lot of press this week the creation of the diplomatic passport
#  I took a beating until I didn't want it anymore, it was there, it's from the universal church of
#  kingdom of god iurd edir macedo and wife really i renewed if it is autorisée day
#  at itamarati to renew his diplomatic passport marcelo accident and his
#  wife was then that is greater when speculated was initially granted
#  passport for him there in the squid government brings was renewed in the squid government of
#  new and after dilma there waiting for the deadline of the fashion authorizing the renewal in
#  will be maintained in what depends on me the renewal of that passport for him is
#  your wife and period, I understand, right?
#  in the hands itamaraty the exceptions and the session is is very
#  welcome in that case if you have an injunction asking to cancel the exit
#  logically, there will be an appeal by the interested party, for sure he will win
#  this action is political demagogy when making it clear who else
#  received the diplomatic passport in the midst of the gospel gospels the
#  deputy also received from the international crisis of grace of god
#  two people received you were here in the case two people usually when two
#  is pure is the husband and wife assembly of god also received two side started at
#  government dilutes the world church of the power of god too
#  received in the dilma government and on my part to renew it also having
#  the event in that sense and also catholic already received 3 is 3 passport
#  diplomatic also with reduced number is not a party is for those who really
#  need he travels all over the world because there are certain is certain the benefits
#  that help in this life sometimes walking around the world avoids queues and I can't
#  often facilitates the baggage check and some countries thought the visa
#  denied and then marcelo wife keep talking here
#  another matter quickly my son of the year is in hungary viktor orban plr and
#  dealing with various issues among them is how does a country that has an economy
#  closed from leaving for the open economy working his role with the
#  chairman of the foreign affairs and national defense commission continues
#  it is not new it is traveling the world he likes to do it there
#  I'm sure of good fruits we also harvested from this trip to hungary I
#  yes I intend to travel there to that region then you can do it is about
#  Poland for us and deepen the ties of
#  friendship as well as obviously getting the news in the press still drop 25
#  percent of murders in brazil in the first two months of this year but
#  as long as the two months of the year go well because of that I will not talk here
#  that what can pressure me i'm not a commentator notion journalist so the
#  numbers speak for themselves
#  I feel the ballad a week is reaching 2 million and the reach in just my
#  page that talk about indigenous leaders that they want to highlight that
#  92 right I worked against how
#  a human reserve has been demarcated as an area twice the size of the Rio de
#  January for approximately 9 thousand Indians
#  is a small internal space is you can call small twice the size of
#  January twice the size of the state of israel where you find it underground
#  there a whole periodic table in the very rich and is confined for question
#  managing this environmental issue are already looking for a country solution because the Indians
#  want to surrender to society the Indians want to let themselves be enslaved
#  by men and for some improvement of politician in awakening millions here in
#  brazil there are many doors direct contact with me what i can do by decree
#  I will do it not being possible to demand a bill for remote fields or
#  send a proposed amendment to the constitution which is almost a consensus
#  among us that that little story that the left always caught right, that the Indian
#  have to live as if you were a prehistoric being since your reservation does not stick
#  cheaper in that regard since 2010 92 when the government started this is without
#  doubt the demarcation of indigenous lands is worth remembering that at the end of
#  sarney the army leônidas pires gonçalves and politics is a land house
#  indigenous indi gol at that time by islands as well
#  logically who is out there looks into Brazil is to have a vision
#  ours you know which one is largely and another largely to change
#  that way we can see outside and inside
#  the first moment, obviously, I’m not marking a large amount of land
#  indigenous people the goal is a wave has been working for
#  some time by the school self-determination to return
#  those big areas new countries being the countries and are going to make relations
#  trade with countries that obviously the mineral issue is in first place
#  so we changed I think we got an inflection point for all of that not
#  we can cross some countries in the more developed than us that we want
#  destroy the amazon we want to make sure the amazon is ours and
#  believes that they have wealth there not only minerals with biodiversity they
#  exploited in a rational way for the well-being of our peoples and in
#  special for peoples days that was the intention of lazio so much
#  how big almost an hour but it has a very good repercussion and the leaders
#  Indians each put their position there like the parecis in the bush
#  who plant soybeans among other things that were fined by ibama in
#  R $ 120 million already knows that he is making this change the attention of
#  obama some time that we cannot change everyone is invited to tender and who
#  this philosophy matters if working is not going to be part of our government
#  now it is an is an organ and breast much more equipped by education itself
#  we are changing people new philosophy is the inspector it has to be the flight was not
#  doing the project is a person of such a pleasant tax until recently it is a
#  dread arrived with a fine a few my life is a muse this morning by
#  kan had to chat with the landowner this changed
#  reads reads in that doom this way started
#  very well intentioned then it became that party everybody knows you know
#  coopting brings artists famous people paper died account would not be the end crosses
#  and I will not speak the name is not big shots defending in the free dilma arrives at the chamber
#  is socialism is is what matters squid is this is what in return I received
#  even believes the limit is time
#  sixty million reais so the artist decided up to 60 million reais
#  or they could receive we spent and 24 1 million reais I think it is high
#  even more tiny 60 times a more tender bid amount but before
#  million reais could be benefited by the law
#  with all due respect it is not possible to do much in particular to put them
#  country land artists so who knows if a career is quite
#  promising in the future the secretary of the play and this is important because it is a
#  party a safe party defense the party which is the safe closed for three
#  or four months a year the fisherman and as he is not going to fish in the
#  time to reproduce he earned a minimum wage per month is
#  welcome to the proposal now we calculate that 65% or two pesos
#  be fraud fraud what do you want to do now like more than 2 billion reais
#  a year with this fight we must fight it there are people who
#  lives on the coast of brazil who knows that the sea water is healthy but receives the
#  closed insurance has a state i'm going to talk to that state avoid problems to
#  forward will say for sure if it would get proof where the government government
#  that state had a password so I did the wedding you know color for
#  phone and call people you know for about a year
#  logically another person lived and make the phone
#  this is the total game just ask don't ask for the piece
#  is what I am a thousand and ended up giving your data and started to
#  be benefited then possible to defend ask your wife has a wife
#  also has a son almost 18 times the amount we put on the other side was the
#  great-uncle neighbor is everybody and of course that little story right
#  look at the government here in such a state and don't forget about us on the occasion of
#  elections your vote is very important that someone
#  I could talk about taking it off, you stay when that person José campaigns in this
#  sense because it is your right to be part of that most humble person are taken
#  that way there is to associate sign up and earn this benefit detail
#  it's very clear now at the end of May and it will launch a re-registration
#  will be able to make those who voluntarily leave the system there without
#  no problem with an ally who has more to stay can receive a lawsuit for
#  I don't really want to do ideological falsehood, but
#  insist that diversion fraud we can't just make up for that
#  jet washout of the bypass millions has to be arrested punished and right now has who
#  commits crimes of this nature is little and trafficking, you know, call everybody
#  of the extensive nearly 2 billion a year are diverted
#  so let's help to combat diversion fraud in Brazil insurance
#  defending is on our radar are humble people who were co-opted
#  we know that we now call for safe defense to come out, whoever may not
#  is a fisherman there is something the leaf and the leaf uol and another world with
#  this our dear são paulo sheet says that our advertising gas was 60
#  using baró of the same period in government time la la humane lie one more
#  lie the spending of last year's period yes
#  for 75 million from the government having ours was 33 million reais
#  now because you want a certain amount in the famous 75 that debts, right, the invoice for
#  December we pay in January and February is none of our business is in
#  previous government so people make this disclosure
#  liar of those numbers the government that said that to contain expenses with
#  advertising is spending more and more still
#  sbt we already spend more than with the globe yet another measure we do not want
#  chase anyone in need of spending spending on ours with mine
#  personal will be spent that didn’t analyze if we can reach everyone
#  has its very important value is the national media
#  we go now we go to a technical criterion
#  right there will be more that home television getting 85% advertising the
#  another 15 percent is going to be business technician and everyone is going to get if
#  logically wants to provide service to the
#  government will receive such a base in birds in privileges to certain in
#  persecute anybody also the freedom of the press I didn't say I can't do it
#  something else talking to sergio louro and paulo
#  garcés we have many tenderers there
#  approved of all this will affect the federal police and we got a thousand
#  vacancies and was carried out in two large groups, right, 500 500 or 600 and 400 still
#  more or less then federal at most will have in its staff more
#  thousand province but exactly to continue helping
#  right in the fight against corruption, diversion fraud and
#  the table the party greatly reduced the government effort is a go-ahead
#  so that these thousand tenderers then reverse used what she
#  think of her an important block here land invasion my mst friends is on
#  first first year last year there were 43 concrete reasons in the first quarter
#  this year only one elevator looks like it was yesterday that 000 00
#  we continue we are the last of the project in that last the project and
#  talk to parliamentarians that is not I cannot the president cannot impose the
#  your will so that we actually end the land invasions
#  on what depends on me will be investigated as terrorism
#  now the other bill also determines the guy doesn’t yet present the
#  campaign promise is but we have to work to get the project in bed
#  fashion to have the smallest best relationship possible sing there the bed is being 81
#  from your opinion and we should do it like once to get there about
#  as little and theorize as possible in half what is most important is to pass the
#  that i want to depend on me i'm not mistaken the italy project was approved
#  similar in the cast it is already detected recently is something in that sense that
#  home invasion or other private property happens a farm
#  a farm, the owner can defend himself against
#  apart from that other side deciding to die private property is sacred
#  the more I have to leave too then our project aims at what
#  defending one's own life or otherwise the legitimate defense of
#  property of yours for your own sake or another is he responds will get punishment
#  this helps us military police officers and federal civilians also in this many times
#  someone is interferes in criminal action in front of that person in front is
#  threatening someone who can kill innocents and back here a citizen who
#  had illegal possession of a gun the policeman a schedule reads interfere will have a
#  problem when there are 10 15 20 years can even be arrested
#  now the case in the rhyme again it has to do with two things is a project of
#  moorish issue of excess is a car stormed the marginal hotel room
#  invade the barracks of 12 shots at a lady was inside
#  the victim's brother-in-law was in the room if it is to put with his gun
#  ended up shooting the bum in the head three times
#  what happens is an example of minas gerais theme of putting how much in the ruler
#  in the July court, there is no reason for that, the conversation in the
#  crime project of the hill speaks of the figure is sure to interest the police
#  also often the police are in a dawn action a circumstance
#  very adverse and he gives more of the style who was shooting him the same if
#  this is against excess he is a source and there are all police characteristics
#  framed will answer for willful homicide in the humor project the excess comes out
#  outside we depend on the chamber and the senate our
#  project
#  next time you’re going to get to bed, then I had the defense of life and
#  own and third party assets can be sure that the violence has gained
#  25 percent now in the first quarter is going to drop a lot
#  this song title can know that nowadays he commits the crime the
#  first especially someone working close to euros if you have him
#  will weigh and act because the hot potato in africa coda the good person and speaks
#  in water we are finalizing the cactus decree to a collector and shooter
#  and hunter we’ll have news the news is what you want us to
#  you deserve it cannot the decree right I always took a
#  law may or may not do that there is really to treat collectors
#  snipers and hunters with all due respect that they deserve and we're going to have
#  a surprise of those seated in defense in this new decree the shards for the
#  steps with assured stability in the armed forces
#  we know that nowadays an official pass
#  the military police of rio de janeiro for example i know it has the size is
#  ensure 24 hours a day and also when going to the reservation
#  we are bringing this to our armed forces there our square
#  establish cured after age in the service is replaced by yours can guarantee
#  after all if a stroll for ten years and you will not be able to carry a gun and have
#  to leave until this morning in iperó yes but it is very simple and had the
#  acceptance of the defense that all of conversation discuss no matter a measure alone
#  so taken in is unilaterally doesn’t work so I started the defense no
#  deal with the matter and practically guaranteed in this decree size for the
#  Praça das Flores the brand obviously whoever I am going to do a second part of
#  the air will have a problem she can for him for them there is a
#  displacement is now holy week traveling or else in the sector of
#  barracks-residence is that way now is not the strong is that will have the right to postage
#  but it is not put the collection will make security left the 19 of the land
#  curiosity on average 25% only the cell phone 6 58%
#  maybe with all certainty by the participation of the security force
#  the episode occurred there is something left to talk about a more
#  important to me, life, we forget about you, there is never anything
#  prevents from leagues thank you very much for the voluntary way you attended here
#  we are in theory são paulo that this woman is easy to attack then it was worth
#  thanks for coming and we are at easter
#  tomorrow a good one for everyone who spends a moment thinking about the
#  pedro case at night makes a better world for everyone
#  a big hug the men a kiss until thursday of next week if
#  god thank you
# hello Eldorado Paulista back Ribeira São Paulo Thursday 7 pm come on
#  a ball President knew right Here André Mendonça our Minister of Justice
#  and Public Safety created in the vessel of God is
#  the neighbor who didn’t give good things to the Valley, he has a president
#  of a military man said and I found out later is that I chose that he was here
#  from the Miracatu region to another Miracatu region São Paulo Ribeiro we are going to arrest
#  here to my left here he does not innovate one wanted to thank here the president
#  of the quadrangular of the quadrangular in Brazil company is already the manga of
#  Oliveira was my colleague Deputy lume ago 30 Toninho is obliged by Selena
#  of the house where our pounds interpreter will stay a while two do with Rose and
#  close here that I go competition right
#  who's starting here on this trip André privilege President you went
#  recognized there in there in Piraí Tapiraí pariquera-açu and now Eldorado is the mother and
#  my wife are not born in Pariquera I spoke for the super there the only
#  hospital in the region at the time, right or was born from Midwife or and there to Pariquera to
#  my mother was born with seven children, you know, and the world is a mixer flower and the last one
#  Vânia went without anyone saying 'here I think the singer did it
#  I said I would be back Armando la Valle is today because we don’t have
#  Miracatu maternity hospital you can see my brother Renato and the captain
#  of the army who see cooked catches no more the plague goat for him
#  the penalty is the deputy and the correct one in the poem the camera and I criticized a construction of
#  My corpse cult he day plantation of Ecuador Look at the banana look and Shirley
#  do not have a border with Brazil so I took it through the Panama Canal to the port
#  from Santos like some from Júlia and the 10 thousand kilometers later a banana
#  Ecuador to walk 10,000 km to arrive in a competitive way or even more
#  get to CEAGESP Thanks for trying at the concierge here let me deliver the
#  phytosanitary control is exercised by the country of yet another control was theirs not
#  was burnt minded 35 is spraying a year in Brazil here in
#  traffic here she calls just that my doubt helps me spraying i'm
#  sending here cheaper we solve protection faces even energy on the table
#  agriculture that could not eat the banana with the plane
#  and today between a plane and a person with the machine on his back, contaminate more
#  pilot or directly in the lavender pay well as we go she Pastor
#  Ricardo went with the pain in active and now great maximum bag to come
#  2014League doing Dilma was the phytosanitary control it's okay Come on
#  recognize what kills her animal that wants to kill her
#  animal has something for that there for me here that I go Maybe already take or
#  take a watch there then I'll take a deal then you say what is the
#  we can take it here, that means boy, what is this, but it was mine
#  childhood the people who were didn’t have much soda is
#  let me know when you leave the Ministry 2016
#  now how am I going to date steady grosenick and the soda left a little bit of
#  glucose you take from the scratch card here in Vale do Ribeira what a scratch card
#  red currant smoothie with shaved ice you went to the beach ice cream she was more expensive in
#  It’s true that she took Cepilho on her son that day, then you guys, the wood
#  right, there was the Pedrão de
#  see if she touched ice cream Wow here I saw the reality there
#  60 meadows and she run here pig is not popsicle it was something other world yet
#  a blow more than that of better-off countries, you know, I bought a little popsicle
#  oe Enjoying here the busy here a farm here under the torpor to look
#  down here you see when i'm not going to ask to go there doing here it took
#  to see how much I was here, souvenir, eight, nine, ten years old, the days in
#  square and sometimes you would go there near the ice cream shop to pick a wooden toothpick at
#  what it was had an iron stamp and you could get the popsicle
#  ice cream popsicle water and milk we only spoke with water that was Matin now good
#  Ah how good it is already punishable by a quick thing here even to be Brazil was
#  for Augusto Nunes Zé Maria and use avoid commenting on something to do
#  question and André obviously that our
#  Minister lazy and few are missing I think the extension of sick pay or
#  by the end of the year it's solved, but at heart it was created to be paid
#  in three times of 6 years it falls when ours by decree by bank plus two and so
#  you economy would be Brazilian economy, right, it's like, it's another contribution, he
#  for you, here are the savings, if I am a big presence and the measure
#  need to pay right with all the leaders no one at that time pro
#  Rodrigo Maia called to see the people also from the Cerrado bed was like a
#  agreement we set the value 300reais he ordering a Provisional Measure to
#  the congress you are not mistaken or you provisional measure the remedy he is a
#  start right video without problem some I think we can send people who lost
#  job I went we have can go after I already said
#  the last two problems ahead of me there is gender and unemployment that me
#  to treat with the same responsibility and at the same time many people thought that
#  love and the positive of staying at home close the world Down happened with a lot of lost
#  their job the informal ones are so were the first hard hit and we are
#  now she is looking for a life that is more and more alive and that she will normally see the
#  the cream portion of an emergency aid 65 million people were
#  hit with vegetable fiber 65 million direct boy almost 50 thousand a month I don't
#  is money that is your wife or regional was like you for you have to be
#  well no but if you have to ok
#  and then with interest and I wanted it to be all percent
#  nobody was ever happening in Brazil was marked with a pen
#  complement with responsibility and each point presented in the Partnership that and
#  pre 60 70 million interest that you pay per year for has a fat still of
#  approximately 140 million I together keep falling
#  and it's silly I can't do that I don't interfere it logically ours a
#  people will fight for what he is happy there I hope man next time
#  caught right In about 30 days Roberto Campos has done a great job
#  you need to know his grandfather federal deputy with me i hope it works out there
#  hence the free small Small Business is also possible special heck that
#  to avoid dismissal for pains one stop paying for the trip could see the
#  reduction of wages at work in the federal government that pay November and
#  slip also has to have a point that I don't know the finger we roll debts
#  status We also think of the loss of states that the ICMS forecast also of
#  municipalities present a loss of ISS that together do not
#  the coach today I by the Supreme Court then our father's
#  going out mana what's happening now here has a curiosity worth it
#  some lines are for him to this train here hydroxychloroquine so more than
#  Parecis AM the foot of the University of Pisa Italy
#  and it was published in the European medical journal saying that thirty percent of motorcycles
#  once using in return around here could be cured why that only has
#  that tar linking this happiness is then what happens there I a campaign
#  some hands intent on tracking the team to the pellucid forehead you have
#  things here i am not a doctor so what i did i like to chase after
#  things so much puts Fidel here warns the North American that he started to study
#  As we can call, we have to talk at the ready station there is a
#  possibility hi how are you
#  is too much presidency stomping the biggest a possibility we know we hadn't
#  scientific proof but that in a way the calf Qual a Previdência the averages and
#  so i started talking about it here and i start treatment new example
#  loves General and how General has to be among the people sells healthy
#  was just and I always said that it is active the losses checks at home for
#  boring the curve don't want to see that you won't get the goal was that you
#  get it later along Detran hit spread the milk that's it and with and
#  with respirators do you remember Prime Minister us who became the
#  Globo's marketer is fixing up I haven't checked yet
#  it is because angry what the marketer says to tell you stay at home
#  when you are missing there you go capital So that they would be troubled to be intubated
#  Vacuum cleaner president So let's buy the respirator quickly paying the bill 30
#  even buy 200 thousand, you didn't know what's going on there, he doesn't see you
#  leg that is making changes silver guys put unfortunate President because
#  stolen the health of the people and the Education of the People should be expelled from life you then
#  unfortunately we have had cases that the federal police have verified that
#  represent the logical acquisitions have to have responsibility everyone has
#  within it for DP the defense within the process now there is evidence of
#  public authorities the crisis where people and thousands of
#  people can die are dying and you make it an opportunity to
#  make dirty money and we can't have more in Brazil so
#  the Federal Police has Total Independence it works together with the
#  Prosecutors, these operations are authorized by the judiciary, many of the
#  times by the Superior Court of Justice according to the level of authority that is
#  involved and what we can say for our society for our people is the
#  following President we have no commitment we have no commitment to
#  them and corruption based on the three determinations of the Lord and
#  our commitments to the people also the federal police will not agree with
#  misconduct so if you want to do the wrong thing
#  and on our part the Federal Police will be attentive will act and in the most
#  quick and logical series doing it with all responsibility André combats the
#  Corruption Ah ok, I won't go into detail here
#  Everyone knows how We choose 23 months now it helps to
#  avoiding the condition of President the best way to fight corruption is to prevent
#  and how do I prevent doing principles of good governance
#  and how good public governance in the world is done by choosing people for
#  merit for the ability to life in a hurry with commitment to the people with
#  ability to respond to criticisms to correct errors and to act in a
#  honest proof and this plan say what you want we are a year and eight
#  months of government we don't have a step of systemic corruption within the government
#  President Jair Bolsonaro's government has been an example of combating corruption at
#  federal police acted like we never have since we took on President we have
#  active Federal victim We have seen a Federal Highway Police active
#  we have seen cooperation with the Public Security bodies of the United States
#  have the numbers here to say May weight that those by the Ministry We have seen
#  records at the Federal Police Record at the Federal Highway Police records at the
#  your joint with the security organs of the States If I want I speak a
#  little TIM number stop by here to take a short break here
#  there is also something who is André the minister Captain Wagner who is the
#  Captain Wagner Wilson at the price of CG the beans what is
#  closed union's controllership-general controls all public administration
#  of the popularity of the public transparency contracts of the Transparency of the
#  anti-corruption integrity it has programs there is no clue what it is
#  an entertaining program there that is done with real time Artificial Intelligence and
#  according to what a public agent is doing, anywhere in Brazil appears
#  one thing say let's see you here do not enter this do not have so much time to
#  you are for So who is there Captain Wagner that the captain of the army did
#  Black Needles Academy tendered for ever needs Army Captain
#  is being made academic and this stuff used in bed sitting
#  best average in the history of the Instituto Militar de Engenharia Capitão Tarcísio a
#  I wasn’t the budget looking Look just answer Joice nothing the size of
#  Brazil we do miracles we are also putting all the bacteria and
#  when he sells old doors for his engineering, that money goes to BNDS
#  for example BNDS in an update of this work of the taxi of the
#  converter with anyone in the center with me obviously a lot with them the money
#  how did i remember atlântica company is worth here take a look here ok
#  here on the Minas Gerais route is one and we have a stretch of the Silva railway
#  the money goes to the DDS, right, and the leleto then studies, does everything, does the study of
#  that we want in office to want I exclude a stretch of the subway there in Belo
#  Horizonte that connects that fat is Barreiro and we here problems
#  we agreed something there could not go to the treasury go there to the BNDS and we have
#  sure we can we have a very good chance of completing a short time
#  this step of the Belo Horizonte subway. Congratulations fast is quality of
#  person you get ours even what you get from running the previous ones to
#  comparison so said a series of transportation in the past that still future
#  here was the focus of corruption and completely changed look at the ports of
#  When Brazil put the distance it was a party fight today Tarciso set up a
#  secretariat within the ministry to prevent corruption has to delegate
#  of the federal police PF PGS da be has there are people from the recipe has military and
#  some that I thought were lifeless and Too Late in government when there were people
#  here there was no commitment there you didn't even care today he was even in the military
#  too much up to and opposition together five months to break the record is also just the
#  start President does not stay in the color of clothes I went there to enjoy a holiday 15
#  days I stayed two days second day I was already crazy Let's go with hers arrives
#  in her color Hi press we are problem i will not enter
#  in detail I called Tarcísio Tarcísio there ok to anyone here as it is
#  which is know everybody is here some problem do not allow everybody
#  then she is putting an omelet to command
#  and what will be accommodated Okay it will mess with the port if it were the general if
#  it could be it could even work but the most appropriate is humiliating is seeing
#  right in the colleague it's working there is no political sponsorship
#  practically right And our government doesn’t even exist We’re doing our best
#  now repeat here metro is Bom Retiro there is a problem there I called Paulo
#  large PG the forró wants to exchange and the tachographs
#  taking the bus Vans trucks right the 12 million tachograph and then millions
#  home school only 1980 who paid the bill I contributed worker does not contribute
#  everyone the owner of the truck the owner of the company and erase more would tell you on
#  end of the line right would be another shot behind him I said to rent PG
#  have to change your cell phone is the director is this PG is everyone is
#  we imploded in this exchange everyone who just knows it has been another take 3
#  kilos did not say something curiosity machine to complete that it will
#  give vaccine here quick game saw the staff is demanding right presence part
#  of the company is not part of the Pingo Doce operation so much that the Zé Maria lunch says
#  what you have left you always had an exempt position regarding this and objective
#  also have no alternative take this And you where you can die I only have
#  that type of medicine, right? that possibility takes it, it needs a
#  scientific background forgot that TV has a newspaper of Death all and 86 of
#  night right newspaper of Death TV that mouth there now
#  I’m in the legal process, your answer is that TV you seek to remove then
#  here demanding scientific proof of antenna education there at the foot didn’t want
#  but nowadays many people support that the vaccine is even applied
#  with this Dilma in the law is not written before the law that exists is in effect
#  okay the law says that teams can be adopted they may not be saying that
#  populated this is the taking such a such a measure But come on and now Manda
#  there was only one project coming from the bed I vetoed a part of that project there
#  I used to talk there about the measures you can use.
#  license price so let's talk about what measures medicines produced
#  there the United States Japan and the European Union and China So what do you get in the project
#  approved what to get here had a maximum of 72 hours here
#  released I went in life because I had some in life talk to me saw
#  she's operating at the bar again at Intermédica, right, it's at Anvisa to see her see
#  here some talk to me i talked and then and then she causes them again on
#  ready look to make a party enter there And then how does it get there
#  I couldn’t take the country test you guys in 72 hours will deliberate that I see it’s
#  that progress has a moment nowadays it has to welcome to distribute and
#  order to pick up in 72 hours I will not go down there that we have here
#  despite being produced in those countries of the block of countries right United States Japan
#  and European Union and China emphasis we have to ask certain questions you know
#  questioning after all right but we cannot be responsible for a vaccine
#  here there is no scientific proof right There is conformation in your relatives
#  of these of these in this one and of the countries but I don’t have here in Brazil
#  that to see deep down they are responsible go to put into the body of a
#  the vaccine because when I said, right, no one can force anyone to take the vaccine
#  vaccine the role no one can force him in the afternoon
#  so yeah but the project this was taken down the
#  I also veto yes 72 hours I did I have not released deliberate is I think
#  what approval fact excuse nothing that i put Juninho is on my side of
#  soil square so it's for training comes to a project feeding the bed and
#  call me on Whats messing up the house I don't remember here present here look there
#  there is a project in the House they are obliged to take the vaccine If you don't get a vaccine if
#  don't wear a mask it's a chain there's no use for a project like this one is the skin
#  398 in the middle issued the PDT deputy I will not say anything no PDT deputy three
#  I can't stand time
#  good then prison sentence for those who wear a mask she fine right I see your love
#  remember It’s left over inside it’s an awareness campaign you see that
#  is a very doctor saying that this mass protects bulhufas bulhufas is another I do
#  here you have it b ****** not going black but who wears old mask
#  Brazilian B ****** cannot be arrested but those who are not wearing a mask will go home
#  use that more than 30 thousand was real so you kill someone you will not
#  arrested until police cannot now enter the kingdom's community at all
#  units of one hour call that every deal certainly didn’t scream screamed
#  the turn back cannot enter today is behind the wheel top shut up
#  and here they will believe you brand can hold this project is approved to
#  difficult to be approved later if it arrives in my life I'm going
#  try I will try this I talk about stealing the wind Look at Pumbaa it's getting
#  Remember that girl I told you how easy it is to dictatorship Brazil that
#  video there having sun that weighs the 29 bad words I had a reserved session
#  I didn't use it here to stay free so fast I didn't say anything
#  people arresting running in the sand in a bikini the undergrowth there and other
#  women learning here in the city on the cake and I didn’t say anything and the
#  Supreme itself a decision that recently had nothing to do with a pandemic
#  speaking of the conditions for you to use Gemma it was almost impossible to use and
#  the policeman here maybe not Gilmar if someone who's sorry for
#  him one thing but I had no people is a teenager swimming who was arrested
#  ladies in a square alone thrown on the floor for and handcuffed there really was the
#  abuses and we have to know how to identify and differentiate the good
#  citizen the Crepe Band and yes we have to have the Rigor of the law the good citizen But we have
#  that preventing educating and guiding has something to do I am not the owner of
#  truth I don't even want to see what goes through me for my cart is ideal O
#  parliament has an obligation and responsibility to perfect projects
#  better now we have an interference in my understand center interference
#  judiciary or quite strong is from this collection
#  and why and I was elected to do certain things
#  that I lose you wrap me up only the Supreme is now analyzing an action
#  a political party on the 200 notes already by the constitution that
#  component there send me to our central bank in case it doesn't have to be
#  in love have to catch who goes this next process soon i will stay
#  taking the time for supreme people after Parkour to disturb people from the Bank
#  Central and now I can say it’s not for I couldn’t, because the wheel does the
#  cats can get cane It will facilitate corruption to fit more money in the
#  underwear wash people she who puts down penalty she makes money that on paper day
#  so the payment by card the virtual payment we keep quiet
#  because I was seeing a run on the bank now, this collection is already practically
#  your personality hit we did a consultation on the fabric
#  I'm in the square with which we did this, some criticized maned wolf Only this one is right
#  there tidying up forever and this was already prepared along the Guará
#  oh hello logically if we had more time maybe we will start a new one
#  screen family only my time as a kid personalities is Pedro Alves Cabral Dom
#  Pedro is so important that they made history in Brazil sir, sell a lot
#  welcome to the lot of getting out to the top already up to fight who has
#  money at home for example is a new cell the guy will have to see himself there if
#  you have free of that resource provided everything even at home is also
#  the maneuver here near pounds brushcutter and tired didn’t change enter here and leave
#  comes in Cristiane Márcia Márcia Max the woman's ass goes heavy screwed her
#  stay married woman you know that the animal catches you
#  can miss her husband right Cristiane da Silva can the bug catch hahaha she
#  also by evangelical coincidence is from the Baptist Church here is one here from
#  Eldorado then is that genre Thanks there and thanks to the Baptist Church of another
#  side small church like that little things there 301
#  is from the Baptist Church accompany us on this trip or Pastor Josué Valandro is in
#  white man comes face to face José as for that one
#  for sale Casa Matinhos talk about saying something
#  liking the trip, I can see that the people seem like a minute, we will
#  need a moment people are understanding that Branco Neves Maria seek
#  rich spindles are poor Brazilians have to pray between writer
#  dry when the government he had the courage of 11 ministers of competence
#  already more seen in the history of the Nation i am very happy president to see the people
#  believing that they will tax, they will turn the tide and you who could for your
#  different wanted to make you an invitation forget that you thought this nation is without
#  God long God bless candle holder God above everything and everyone something there
#  of Sesi Senai and then we go since we are a
#  the region of a Federal Highway Police post which is very common
#  you will see your Federal Highway Police agenda and Registry working
#  I had a problem registration was solved the hair knows what
#  it happened is I talked to André talking to a page who is the director general
#  of pf he quickly solved a problem that happened at the PRF post
#  registration and we will say it is I think it will be there right To give a
#  stop will be free for an hour watching the police use the police
#  federal highway is feeling the problems they may have I
#  I know the clay you must not be aware of there I think it is the director-general
#  from the pf he traced the shapes a same question of radars that starch she ends up
#  with the radar of Brazil that I get a mobile no longer exists Federal super
#  Of course I will talk Do you want to talk has
#  who was late here has a problem Take it, you can talk, give me a teaspoon
#  router stays here it keeps talking about the time there so we have a new standard
#  for the application of fixed radars that really will not have radar
#  tree now wanted to end you happened that is you have justice see
#  you really have to have 1,800 radars in Brazil so I’ve already hit the color News
#  Tarciso he has already raised with geographic coordinates I did better
#  acquaintances you will make the air that if we publish it’s left of the geography of
#  all to give their place where they will keep out of that relationship if it is
#  television is wrong we are going to take a family State Highway then I can't
#  nothing is planned, maybe it has already happened The Senate voted
#  the project moves the national traffic cosmo the Initial proposal my era
#  so that the driver's license appears for ten years then 65dw in bed
#  of a stir remains ten years but until 50 years of the nobody can accuse
#  that would be in question because she 65 already have 66 times does not give André here
#  the son harm me now calling 50 with 50 in the hair 46 47 I will do 40
#  is here is getting lost hair is
#  and it's an advantage that he's going bald, his hair is going to be wet, right?
#  among other things you still the end of the stirring we play active
#  and those clinics that do medical exams, right, our project abolishes here in
#  you could make the doctors your gift I have a son with yours
#  father a friend and among other facilitations is how it competed itself Observe the
#  future another if you ended up with an obligation was that thief simulators
#  Help me out there dude ended up with simulators, the price dropped and more or less 300 more
#  you also that the medical examination also falls approximately 280 pesos to
#  driver's license which is a lot of cars in Brazil but that's okay what we
#  able to approve this year is welcome as the case may be it can only
#  represent any other similar project 11 following it presents itself
#  project a following that makes it easier you will get your wallet and more
#  cockroach It's hard to wash your number ok
#  the job is five years in the United States it's easier you study do your
#  proof goes to the bureaucracy is still very big do not have week by week
#  in Caldas Novas we’re showing photovoltaics and that I talked about here
#  at the moment, it’s too late, forget about technology, research the minister
#  but he was an exceptional guy but he lacks the resources He makes a possible
#  but we have some already exists in Brazil He has been talking to identities in
#  opt even dental fine to have the super battery of 9 Dracena and where what
#  what happens to this one because different super batteries here you have today in
#  day there if God days and try to put a load all the time
#  the piece of niobium graphene you can be a load quite fast right now
#  a few minutes Imagine you speak at the health center reason will have a coffee the amount o
#  civil toilet College found here at home heart help she goes on the arm an all
#  back 1,400 km until I said to a deputy there that
#  and hers, right, the fusion is seeing a great love 15 Urban energy
#  photovoltaic here can be the power to drive the future to the car there a
#  carguinha and then control people we can have buildings with that something else
#  will be recharging cars the color electric energy
#  the PEC of the reform of people is ending, I can already see
#  using quickly talking a lot of [ __ ] first do not apply
#  Current servers may be going forward
#  and I will not go into details are the conversation now will analyze will alternate
#  going to extend to the other powers maybe the executive's boy being
#  reforms have been made on top of some active saying boxes will continue to be
#  Federal arrest the highway police Haggai Haggai he was the game there the most
#  diplomats diplomats is now just a military man for example if someone wants to
#  Military all things saving things saving we don't have the extra in the time of
#  guarantee doesn’t have a lot of things It’s true the stability the conversation in the
#  service not three so no one wants to compare anything no priest aches filled
#  much in Brazil to the mayor of the past more than doubled the number of
#  servers and points is another to pay I'm eating Federal that weighs more for
#  we are the server president there takes care of the civil servant the results are no less
#  everything worked out I can't congratulate you on the President's reform you how old the
#  ministry not reform administrative reform ceiling button here
#  one more one more one more here also goes at night I brought principles of
#  public governance Transparency New methodology for accessing reforms
#  administrative authorities in the world have always worked with a very strict criterion for
#  access to the public service and all this is foreseen in the administrative reform without
#  prejudice to the attractive rights of collective problems, let's play fast
#  here at the tip of Pingo Doce Facebook 22,000 our
#  to 128,000 so ours here I took to Jovem Pan News 10,573 fight giving a bath to us
#  raised agreement cut young here We will put more that is just to end
#  here, nothing ends in a little while back, young man, here we go, I don't have Augusto
#  Nunes Zé Maria uses Victor here you will fall in love with this journalism from
#  Jovem Pan focus of Brazil 12 thousand in Folha Politica four thousand in total is 128 thousand
#  more we know here that it exceeds 300 thousand people here watch this here has
#  seen other other blogs blogs interviews on my daughter questions
#  some idiots the first one here André you are
#  the Christ participation of the ministry heads this recent operation that took place
#  in Minas against Gold leaders who are members of the PCC, this operation was
#  conducted by the Federal Independence Police I can tell the
#  mega-operation perhaps the largest operation in the history of the federal police more than a thousand
#  police over 400 people arrested hear the biggest blow ever taken in Brazil from
# ...
#  that you use afterwards cannot recycle and the electric car out there in general is
#  fueled with coal and electric internal gas here not our car has the
#  ethanol has the ethanol you plant it captures carbon it turns into biomass afterwards
#  to generate energy and you have given all the support to the sector
#  then the entire surgery and with all the ills is the emission of
#  carbon in Brazil as a percentage of the emitted in the world Complete Brazil
#  present the migrant because they are the construction of the text We are not the villains of
#  greenhouse gas emissions in the world, that is, this discussion of climate change
#  it is the fault of the developed countries that in the Industrial Revolution they cut
#  their forests used wood for coal locomotive for sleeper from
#  railway continue to burn fossil fuel while ours in general is
#  ethanol Our energy is right and hydraulic is Lika is
#  photovoltaic that that solar is biomass We are not responsible for the
#  emissions in the world we have commitments to make but no one can even enjoy the
#  Brazil this responsibility we are three percent the only for me to have a
#  idea a question of comparison all Latin America together all inclusive
#  Brazil represents seventeen percent of what I only found on my own if you
#  I am more United States Europe much more than Brazil then and the countries
#  you know then you need to put things in their right place we are not villains
#  of the climate issue at all so the Brazilians who are in the
#  internet before that was I’m suggest ask for information before criticizing is
#  criticize all the time with their famous villains in the world in this issue of emission
#  of CO2 and we are down there even for the size of Brazil you very 500
#  territorial extension your life even right the territorial extension and we are one of
#  latest CO2 emissions so Brazil does its part now it is not together with its
#  critical because with your criticism you do because more and more information
#  fans goes outside of Brazil and from there
#  what is the consequence of this are actually campaign out there to boycott product
#  Brazilian made even by idiots a Brazilian just made the guy very
#  known does not speak the name of not believing problem is that I speaking no
#  buying in Brazil is now a guy who doesn't really have a very good life right
#  and live as if he were a maharajah live in the world of the moon as a tycoon training a
#  it happen now you humble without hunger better where to stay is simply
#  relaying sharing the liars Mateus about our Brazil I said
#  for you you catch over the past 20 years that everyone has caught fire in
#  some Amazon region and in the Pantanal rarely the year that doesn’t take what doesn’t
#  caught fire there you are going to count all the areas announced The fires you have already
#  burned the sea is the size of Brazil number
#  calls it week the visit of the American secretary Mike Pompeo had a
#  I sent our Minister of Foreign Affairs Renato Araújo over there
#  as well as a defense representative from where the army forgot his name
#  here also accompanied the manager of Roraima And of course he went to see her
#  question of the welcomed operation does not think that the American has an interest in
#  reestablish democracy in Venezuela now I will not speak one of the country either
#  there is another country here in South America but in the south that you are buying for
#  where are they going by the wrong option?
#  already demonstrated in the past and follow the São Paulo forum line and now the
#  having a mistaken vote there was even very angry made the left
#  responsible for success in that country came back to power and quickly and
#  you can see the regime similar to ours in Venezuela ending right look
#  here you’re playing ball in my head okay it’s circulated a lot this is it and
#  freedom of speech now if it were the opposite it would be passive fake news of
#  passive to revoke the arrest warrant and seta has no one more than me who
#  suffers fake News in Brazil and suffered during the elections
#  the accused all the time and racist homophobic fascist misogynist does not like
#  northeastern and has a process in the TSE to remove my plate right as if I had
#  been elected by fake News I ask any of you who received any
#  your phone that you didn’t know origin is the fruit of the boosting fruit and made
#  you change the vote has not received anything until today information from anyone who received
#  in operation someone received the cell phone here to speak
#  on elections could change your vote right from the duty to vote in the PT vote in the
#  third and did not have and unfortunately has a process until the third gives
#  to play this process I am absolutely sure here will be filed in that
#  right, even for the sake of justice We will not have a vote for that
#  that I'm sure of that go to the TSE and everyone is aware of what happens
#  in municipal elections in São Paulo do not know how to say that you must have a
#  candidate is already talking there but I will not speak the name help us too but I
#  I have a jacket with but I will not say his name ok you have to help
#  thinking also I will not talk about one of them and there is also a candidate in Manaus not
#  I will speak his name right and obviously if you vote needy little bee and want
#  you already know who to vote for in São Paulo who are talking, you know you were going
#  put São Paulo later you will find me here for you You will like him
#  however he is a person that I know everybody, right? And I hope he grows up and
#  research was the child for us to learn an audience in Manaus we have a
#  excellent candidate there and the but I make your commitment not alive not
#  enter into municipal ones Although, and we can change our mind too
#  right and because if it reaches such a point and I think I can influence the
#  elections in these three, right, three cities, I will speak out because I think
#  this candidate our seeing is has everything to make a good mandate for the
#  well from São Paulo de Santos or Manaus AM
#  is well the young man we plant the screen is in the air here
#  pingo nos is on Facebook YouTube is not with 32 thousand people online pingo nos
#  is 82.000 Jovem Pan 9000 then 91.000 Jovem Pan left us in the dust
#  I recommend you when you're done with the Live scale here Sintonia Jovem Pan
#  symbol Zinho to watch there Augusto Nunes is on vacation Victor grade if he uses
#  and Samaria ok will stay to see the question are you
#  I will ask the question here is it accumulated because of the pandemic is almost
#  40 ambassador nominations around the world are approved and we are for Israel is
#  a huge meandering army general was going there Okay, he made a contact with the
#  during that time practically all the governors with practically all the
#  senators then sought from the authorities that he would like
#  Ambassador to do there on my part I told him that there was already
#  talked to Benjamin Nathaniel by coincidence
#  with I found him Colonel of the Israeli army who is Ambassador here in
#  Brazil that I would like to see done, among other things, something like
#  the Rondon project in the past our kids went to Israel to stay there
#  average 30 days of the clerk for free the only requirement is that we speak in English
#  the scene is in no condition Send someone to say that I don't speak English is today in
#  almost unacceptable day in someone who does not speak another language for your
#  own well and for your own professionalization to see the
#  fish farming in the desert see how it works agriculture la la la la it rains
#  less than ours our carille our sertão and how does it work there the
#  Culture how do you get them beyond the food guarantee and not support
#  part is for Europe starting the technology too so this is the General
#  getting there already has carte blanche to get to Israel go to club
#  sense for us to do something similar to the project go to send Our
#  kids at university in Brazil all free of charge to do an internship there in
#  exam Because it is a good problem program there is an example video let's go Ask if
#  use with the word
#  So [Music]
#  conditioning good night is in your opinion What are the three
#  main lies spread today about the Amazon in the world thank you
#  the rain can name several but first is the following that the amazon
#  dismantling the Environmental Protection system is not true when
#  otherwise we receive ourselves and that we receive the Protection system
#  Environment to care for the Amazon dismantled Half of the staff
#  bank employees you saw me for example it was lacking investment
#  budget and strategy the first thing according to people say look
#  you are imposing the population of the Amazon the model that they do not want
#  it is not true as president today quoted here several indigenous lands the
#  cinta-largas in Rondônia the Parecis in Mato Grosso Caiapós munduruku there in Pará
#  where we had an operation recently several of them want many
#  is to work with agriculture others to have some degree of exploitation of their
#  mineral wealth is the greatest in Brazil so it is not true that we are
#  a point we are present has said have to respect what people want
#  the places that a big lie that’s said there is that the amazon is being
#  devastated now we have 84 percent of the Amazon preserved since the
#  the Portuguese arrived here today 84 everyone who lives in the Amazon person
#  think the Amazon an empty place has 23 million Brazilians there is not the
#  empty place people need to produce need to live need to get around and
#  still 84 percent is preserved What you need in the Amazon is
#  sustainable economic development that As our Paulo Guedes said in the
#  President still out there has no worse enemy for the environment than
#  poverty EA Amazonia has been left in poverty the richest people in the world are in
#  Roraima you find a periodic table right under the ground no
#  thing is not underground because the gas is very clear he
#  the greedy EA is there these great the Band were not demarcated it was not
#  coincidence right is where in the subsoil there are immeasurable riches like the region
#  of the six lakes for example the start also doesn’t stop is an area back there
#  for Pedro Figueiredo's decree has been safeguarded for a possible
#  decoration in the future was almost handed over to other companies that would
#  just for that region and so that good time and the operation was suspended and we
#  we wait for an opportune moment to see how to explore this and we have a project
#  As I said at the beginning now wires here allowed exploration, right, the mining in
#  indigenous lands That's it, it's not going to authorize just to update but it has
#  to have here the science of the Indian for such now while you do it the
#  irrational exploitation is happening right and we send it out
#  large amount of Gold lover among other ores is number another
#  question is Zé Maria and
#  It is but not very good night President Jair bolsonaro good night tells me Ricardo
#  Salles happy I would like you to talk about what Brazil can do what
#  can be done to recover Brazil's image in this war for the labor market
#  agribusiness right and more what is the origin of these attacks of all is
#  resistant Brazilians cheering against the country Felício
#  ok Zé Maria I would say the following was my place is a shame we have
#  Brazilians who spoke ill of their own country here to resonate abroad
#  or let's go out there and speak ill of Brazil either in seminars or meetings
#  whether in newspaper articles Whatever it is why does that happen that the
#  president was the first president in the last decades that is taking away the right
#  matters under the rug is amazonian politics was the ostrich policy
#  sticking your head in the hole pretends you no longer had illegal mining in the land
#  indigenous and no longer had theft of wood and no longer had land grabbing and for
#  that it had all this because the people didn’t even want to discuss these issues and
#  the president bolsonaro in a coherent and serious way is bringing these
#  matters to be debated in Brazil people go out there to complain that we
#  we also closed a lot of taps on the mouths here inside the lot of
#  entities a lot of organizations a lot of academic do this all that
#  it never ended, you know, but I kept taking the money from our government
#  I will then, if it passed by the government, we need the tap, everything is ok
#  screaming out there is also love goes out comes out of it
#  the coast on Oi good night president 'good night
#  Minister Minister in Tuesday's speech at the UN General Assembly the
#  president bolsonaro drew attention to this problem of the campaign of
#  disinformation promoted against Brazil abroad and spoke about Indians and
#  caboclos who also burn their shoes in the Amazon rainforest sir
#  could you give us more details about that Minister for us who are here
#  the distance following all this question of the Amazon these fires
#  made by Indians are also illegal or in some cases they are allowed
#  by law and that if prohibited, the authorities are able to supervise
#  are able to impose fines when necessary even if they are within
#  indigenous territories how's that like this scenario thank you good night
#  for us president And Vitor is what the gift sold and
#  has every reason following a culture of fire management it is a culture that makes
#  part when you don’t have technology in places What’s the way to produce
#  agriculture cuts set fire and plant until you go using one two three plantations
#  three times you cultivate on the fourth he changes that I small farming
#  communities related to india also does this is part of the culture this wants to
#  to say that any burning that has in the Indian Amazon the caboclo Of course not
#  that is not what the president meant but he meant that it is part of the culture
#  the fire involved in the production, which is even made with
#  low-tech places in Brazil where high technology is employed you don't
#  have use of Fire because you have other ways to clean the soil to prepare the
#  this is what the president wanted to say and the true truth, right? We have
#  really this culture impregnated in Brazil people go out there and said
#  look at all the fires are
#  criminal fires no it's not true there is a part that is criminal is being
#  investigated by the police in any region who hear arson he
#  Indians and traditional communities that use fire will be investigated
#  in relation to their culture, there is a dispensation even from the Decree that the
#  president signed it is important to remember in this signed a decree banning
#  the use of fire in Brazil for 120 days except for those who need the
#  fire or for researching specific cases or for crops for example sugar
#  from the Northeast you don't have a lot of mechanization is a way to clean the
#  place to harvest is the use of fire in the same way the indigenous EA
#  traditional community you respect traditions but prohibit excesses this is how
#  that public policy is made the way the present did the decree in heavy
#  coastline and it's wire Zé Maria Thanks naked
#  I want to watch television from the crowd of our Live, thank Leticia here
#  also who kindly attended here to be our pound interpreter if
#  I'm not mistaken I'm five million more people have a hearing problem
#  or audition speech Okay so there are a lot of people who accompany us because of
#  thanking that Carlos Sales an a
#  most expensive thing just to say that Dona Michele asked us to record a video
#  right in honor of the Day of the Deaf if I am not mistaken to correct myself here if
#  you were wrong It was like this like this, right, so I congratulate you anyway, I already
#  I recorded like this I think I'm crazy not to record immediately This video is
#  I already recorded it I was not careful it can only be a sin for the person Thanks there
#  until next week who's on my channel Tune in Jovem Pan symbol
#  Zinho has 15 minutes there for you to hear the final comments there must be
#  of our young lady friends that next week if God he

# %%
### Criar documento único
## 3. Salvar Data Frame a partir de 'results' com as colunas id, start, end e text.
results_df.to_csv(f"{DATA_DIR}/LivesBolsonaro_SubFirstSum{context}.csv")

# %% [markdown]
# ## 1. Limpar documento

# %%
df = pd.read_csv(f"{DATA_DIR}/LivesBolsonaro_SubFirstSum{context}.csv")

# %%
len(df)
# # df.id[0]
# Out:
# 31706

# %%
# df.head(11)

# %%
# for i in results_df.id:
#      print(i)

# %%
# criar colunas com o id e link para os vídeos
df[['dir_path','sub_doc']] = df.id.str.split(f"{SUB_DIR}/",expand=True)
df[['video_id', "doc"]] = df.sub_doc.str.split(".vtt",expand=True)
df["video_link"] = "https://www.youtube.com/watch?v=" + df.video_id

# %%
# apagar 'dir_path', '"doc" , sub_doc' 
# renomear "id" para "vid_path"

df.drop(['dir_path', "doc", 'sub_doc'], axis=1, inplace=True)
df.rename(columns={'id': 'vid_path'}, inplace = True)
df = df[['video_id','start', 'end', 'text','video_link', 'vid_path']]

# %%
df.head()
# Out:
#          video_id         start           end  \
# 0  J9u1Cl49xlw.en  00:00:00.000  00:00:10.469
# 1  J9u1Cl49xlw.en  00:00:10.469  00:00:17.609
# 2  J9u1Cl49xlw.en  00:00:17.609  00:00:23.580
# 3  J9u1Cl49xlw.en  00:00:23.580  00:00:29.460
# 4  J9u1Cl49xlw.en  00:00:29.460  00:00:33.450
#
#                                                 text  \
# 0  it's good night everyone makes our farm lainé ...
# 1   hours of the night and let's go here quickly ...
# 2   can happen is happening the government time s...
# 3   in advance the day of our success and there i...
# 4   I said that in the press the press is importa...
#
#                                        video_link  \
# 0  https://www.youtube.com/watch?v=J9u1Cl49xlw.en
# 1  https://www.youtube.com/watch?v=J9u1Cl49xlw.en
# 2  https://www.youtube.com/watch?v=J9u1Cl49xlw.en
# 3  https://www.youtube.com/watch?v=J9u1Cl49xlw.en
# 4  https://www.youtube.com/watch?v=J9u1Cl49xlw.en
#
#                                             vid_path
# 0  /Users/dumoura/Dev/PDev/PoliticalRemix/Lives_d...
# 1  /Users/dumoura/Dev/PDev/PoliticalRemix/Lives_d...
# 2  /Users/dumoura/Dev/PDev/PoliticalRemix/Lives_d...
# 3  /Users/dumoura/Dev/PDev/PoliticalRemix/Lives_d...
# 4  /Users/dumoura/Dev/PDev/PoliticalRemix/Lives_d...

# %%
# Salavar em csv o doucumento "LivesBolsonaro_Subtitle" na pasta "data"
df.to_csv(f"{DATA_DIR}/LivesBolsonaro_SubtitleCl{context}.csv")

# %% [markdown]
# ## 2. Primeira pesquisa documento
#
# - quais vídeos na Live da semana são mencionados os termos hidroxicloroquina, cloroquina, ivermectina ou azitromicina?

# %%
#df = pd.read_csv(f"{DATA_DIR}/LivesBolsonaro_SubtitleC_{month}{day}{year}.csv")
title = f"/LivesBolsonaro_SubtitleCl{context}.csv"
df = pd.read_csv(f"{DATA_DIR}{title}")

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
#azitromicina
early_treatment = df[df.text.str.contains(r'chloroquine|hydroxychloroquine|azithromycin|ivermectin|early treatment', case=False)]

# %%
# len(early_treatment)

# %%
# early_treatment.head(5)

# %%
# for link in early_treatment.video_link.unique():
#     early_treatment = link
#     print(early_treatment)

# print(len(early_treatment))

# %% [markdown]
# **R**. São os 46 vídeos ascima

# %% [markdown]
# # Querying - Live da Semana
#
# Which videos in Live da Semana mention medicine hydroxychloroquine and ivermectin?
# When? How?

# %%
#df = pd.read_csv(f"{DATA_DIR}/LivesBolsonaro_SubtitleC_{month}{day}{year}.csv")
title = f"/LivesBolsonaro_SubtitleCl{context}.csv"
df = pd.read_csv(f"{DATA_DIR}{title}")

# %%
len(df)
# Out:
# 31706

# %%
Chloroquine = df[df.text.str.contains(r'hydroxychloroquine|chloroquine', case=False)]
ChloroquineIvermectin = df[df.text.str.contains(r'hydroxychloroquine|chloroquine|ivermectin', case=False)]
EarlyTreatment = df[df.text.str.contains(r'early treatmen', case=False)]
PacificWar = df[df.text.str.contains('the war of the pacific|pacific war', case=False)]
CapitaoCloroquina = df[df.text.str.contains(r'chloroquine|hydroxychloroquine|azithromycin|ivermectin|early treatment', case=False)]
Virus = df[df.text.str.contains(r'little flu|COVID-19|flu|colds|pandemic|coronavirus', case=False)]
BrHealth = df[df.text.str.contains(r'mask|isolation|lockdown', case=False)]
Blame = df[df.text.str.contains(r'media|folha|globo|pt', case=False)]

# %%
# Chloroquine
# ChloroquineIvermectin
# EarlyTreatment
# PacificWar
# CapitaoCloroquina
# Virus
# BrHealth 
# Blame

# %%
# Save
Chloroquine.to_csv(f"{DATA_DIR}/LivesBolsonaro_chloroquine{context}.csv")
ChloroquineIvermectin.to_csv(f"{DATA_DIR}/LivesBolsonaro_ChloroquineIvermectin{context}.csv")
EarlyTreatment.to_csv(f"{DATA_DIR}/LivesBolsonaro_earlyTreatment{context}.csv")
PacificWar.to_csv(f"{DATA_DIR}/LivesBolsonaro_PacificwWar{context}.csv")
CapitaoCloroquina.to_csv(f"{DATA_DIR}/LivesBolsonaro_CapitaoCloroquina{context}.csv")
Virus.to_csv(f"{DATA_DIR}/LivesBolsonaro_Virus{context}.csv")
BrHealth.to_csv(f"{DATA_DIR}/LivesBolsonaro_BrHealth{context}.csv")
Blame.to_csv(f"{DATA_DIR}/LivesBolsonaro_Blame{context}.csv")

# %%
BrHealth = f"/LivesBolsonaro_BrHealth{context}.csv"
df = pd.read_csv(f"{DATA_DIR}{BrHealth}")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
# Which
for link in df.video_link.unique():
    videos_cloroquina = link
    print(videos_cloroquina)
# Out:
# https://www.youtube.com/watch?v=2tB4XLKXSeI.en
# https://www.youtube.com/watch?v=F9jXlF2ExQE.en
# https://www.youtube.com/watch?v=ZLIUvoZDSFc.en
# https://www.youtube.com/watch?v=rSO0DszwUbA.en
# https://www.youtube.com/watch?v=XceWFVE7QLc.en
# https://www.youtube.com/watch?v=8oPisf3kbGI.en
# https://www.youtube.com/watch?v=8Cn1PGmlJuk.en
# https://www.youtube.com/watch?v=WLd2HmL3Ua0.en
# https://www.youtube.com/watch?v=ALFq4eHRUo0.en
# https://www.youtube.com/watch?v=Ea5ZK0Fr5TM.en
# https://www.youtube.com/watch?v=YCliiy_yl9Y.en
# https://www.youtube.com/watch?v=ZZj93uz78NE.en
# https://www.youtube.com/watch?v=AhySjAMku18.en
# https://www.youtube.com/watch?v=GVzh8k6YjKU.en
# https://www.youtube.com/watch?v=S28DvOuB6cM.en
# https://www.youtube.com/watch?v=P3B8L5ql5GM.en
# https://www.youtube.com/watch?v=5wTrE6F5jlc.en
# https://www.youtube.com/watch?v=UqEQfL6il8M.en
# https://www.youtube.com/watch?v=oVIJD_tuRPY.en
# https://www.youtube.com/watch?v=vNyBRsVZ0gg.en
# https://www.youtube.com/watch?v=VuMbYrq_ys4.en
# https://www.youtube.com/watch?v=CaTtyaM5Jlw.en
# https://www.youtube.com/watch?v=-4vo-vjUuNE.en

# %%
for texts in df.text:
    print(texts)
# Out:
#  don't wear a mask it's a chain there's no use for a project like this one is the skin
#  good then prison sentence for those who wear a mask she fine right I see your love
#  here you have it b ****** not going black but who wears old mask
#  Brazilian B ****** cannot be arrested but those who are not wearing a mask will go home
#  quarantine social isolation suspension of activities you who are not working
#  we should in the middle and there is to go for vertical isolation
#  complications there may be more serious complications then i'm wearing a mask
#  appropriate mask for that to pass my side that I still remain under
#  masked people here the interpreter the brand president everybody
#  used to seeing that broad smile from the president came in a mask and saw the
#  minister with this mask is different hers is blue and mine but this shape
#  meet with a mask like this is the reason we put it on to show how
#  president is going to have to dispatch from here we are going to recommend the isolation
#  is completely from the end of the quarantine isolation they forgot the
#  social distancing from wearing masks is now no problem because it is a
#  operations here were the mask of more than 30 yard exercises
#  measures taken by many governors and mayors of total isolation ok
#  so I use a mask here now the vaccine card is here so here is the
#  tired of this mainstream media and the president already knows the mask has been off for a long time
#  also to the effects of isolation and everything else twice as many emerging countries
#  positions there is favorable isolation finding food favorable to
#  the flattening of the curve was talking about here, the isolation had to happen
#  of isolation and everything that has to do with the behavior of the people their
#  another project which has to do with the use of a mask
#  train others with the animal okay know about isolation okay but a country
#  the respiratory aid which is that oxygen catheter nose to mask
#  normally we will wash more siblings we will wear a mask sometimes inside a
#  few states, right, or municipalities are adopting this policy of isolation from that of
#  this mass that was used there the diving mask will make you nervous but
#  without a mask it's okay remember that today, July 2nd is the national day of the fire fighter
#  show myself here I could be fined now because I'm without a mask
#  I advocated vertical isolation and not this horizontal one, everyone stays at home
#  today we came here and the isolation, right, the confinement Lock
#  millions of children out of the classroom and the indiscriminate lockdown that
#  of masked people no wonder that the population is what the community zap and thank god
#  Madeira Ordinance of March 20, Ordinance 454 determined the isolation
#  less I wrote a little bit wrong here ie isolation also take away
#  in bad faith but as it didn't work I always advocated vertical isolation
#  responsibility for the mask collection I will not say much because it will still
#  now of social isolation whether or not you like science is an app is the
#  impact of free social isolation on pregnancy for 12 months and
#  entity the council someone is defending is isolation for students until the
#  negative effects of the period of social isolation and removal of children from
#  will have to be delayed because if we stay we will continue with the isolation
#  regarding the isolation correction there is no point this has a new protocol
#  fines for non-compliance with the duty to wear a mask I will not teach one a
#  federal law here to change by the mask wearing components where
#  everything is related to isolation and job detachment everything helps me from
#  requirement of the mask on public roads practically he opened all trade
#  right and if we say we tell you that the mask avoids contagion
#  I'll be able to work wearing a mask because if I can't work with a mask
#  also with a mask 24 she could sleep and with the lengths to
